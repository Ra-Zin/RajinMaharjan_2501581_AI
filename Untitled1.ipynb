# %%
import pandas as pd
# Load dataset
data = pd.read_csv ("student.csv")
# Feature matrix
X = data.drop ( columns =["Reading"]) # Drop target column
print ( X.shape ) # ( n_samples , n_features )
# Out:
# (1000, 2)

# %%
# Limit classes to the first n_class (e.g. , 2 classes )
n_class = 2
filtered_data = data [ data ["Reading"] < n_class ]
X = filtered_data . drop ( columns =["Reading"])
y = filtered_data ["Reading"]
